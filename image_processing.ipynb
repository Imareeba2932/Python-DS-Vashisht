# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import numpy as np

# %%
# creating a 'red' image of 256x256 pixels
red_img = Image.new('RGB', (256, 256), color='red')
red_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
np.array(red_img)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        ...,
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)

# %%
circle = Image.new('RGBA', (256, 256), (0, 0, 0, 0))
draw = ImageDraw.Draw(circle)
draw.ellipse((64, 64, 192, 192), fill='red')
draw.ellipse((78, 78, 178, 178), fill='green')
circle
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %%
circle.save('my_circle.png')

# %%
img2 = Image.open("goku_collage.png")
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
print("Image Properties")
print("Format: ", img2.format)
print("Mode: ", img2.mode)
print("Size", img2.size)
print("Width: ", img2.width)
print("Height: ", img2.height)
print("Palette: ", img2.palette)
print("Info: ", img2.info)
print("Filename: ", img2.filename)
# Out:
# Image Properties
# Format:  PNG
# Mode:  RGB
# Size (512, 512)
# Width:  512
# Height:  512
# Palette:  None
# Info:  {}
# Filename:  goku_collage.png

# %%
img3 = img2.resize((256, 256))
img3
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(45, fillcolor='white')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(-45, fillcolor='white', expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=364x364>

# %%
img3.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# concatenating images
img4 = Image.new('RGB', (512, 512))
img4.paste(img3.rotate(45, fillcolor='white'), (0, 256))
img4.paste(img3.rotate(-45, fillcolor='white'), (256, 256))
img4.paste(img3.transpose(Image.Transpose.FLIP_LEFT_RIGHT), (256, 0))
img4.paste(img3, (0, 0))
img4.save('goku_collage.png')

# %%
# blending images
Image.blend(
    red_img,
    img3,
    alpha=0.5
)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
a = Image.open("goku_collage.png")
b = Image.open("goku_collage.png")
print(a.size, b.size)
print(a.mode, b.mode)
c = Image.blend(a, b, alpha=0.4)
c.show()
# Out:
# (512, 512) (512, 512)
# RGB RGB

# %%
a.convert('RGBA') # convert to RGBA mode
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %%
d = Image.new('RGB', (1024, 1024), 'blue')
Image.blend(a, d, alpha=0.5).resize((256, 256))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 d = Image.new('RGB', (1024, 1024), 'blue')
# ----> 2 Image.blend(a, d, alpha=0.5).resize((256, 256))
#
# File c:\Users\LENOVO\miniconda3\lib\site-packages\PIL\Image.py:3325, in blend(im1, im2, alpha)
#    3323 im1.load()
#    3324 im2.load()
# -> 3325 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# ValueError: images do not match

# %%
# when sizes or mode mismatch
a = Image.open(r"C:\Users\ZAID\Pictures\goku.jpg")
b = Image.open(r"C:\Users\ZAID\Pictures\Picture5.png")
b = b.resize(a.size)
b = b.convert(a.mode)
print(a.size, b.size)
print(a.mode, b.mode)
Image.blend(a, b, alpha=0.5).resize((512, 512)).show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [35], in <cell line: 2>()
#       1 # when sizes or mode mismatch
# ----> 2 a = Image.open(r"C:\Users\ZAID\Pictures\goku.jpg")
#       3 b = Image.open(r"C:\Users\ZAID\Pictures\Picture5.png")
#       4 b = b.resize(a.size)
#
# File c:\Users\LENOVO\miniconda3\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ZAID\\Pictures\\goku.jpg'

# %%
a = a.resize((300,300))
blur = a.filter(ImageFilter.BLUR)
outline = a.filter(ImageFilter.CONTOUR)
emboss = a.filter(ImageFilter.EMBOSS)
light = a.filter(ImageFilter.MaxFilter())
dark = a.filter(ImageFilter.MinFilter())
sharpen = a.filter(ImageFilter.SHARPEN)
blur.show()
outline.show()
emboss.show()
light.show()
dark.show()
sharpen.show()

# %%
circle = Image.new('RGBA', (256, 256), (0, 0, 0, 0))
draw = ImageDraw.Draw(circle)
draw.ellipse((64, 64, 192, 192), fill='red')
draw.ellipse((78, 78, 178, 178), fill='green')
font = ImageFont.load_default()
draw.text((128, 128), 'Hi!', font=font, fill='white', anchor='mm')
circle.save('my_circle_2.png')
