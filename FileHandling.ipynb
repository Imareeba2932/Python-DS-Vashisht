# %%
import os #knows about floders, files or directories

# %%
print('Current working directory is:', os.getcwd()) #getcwd() is a function that returns the current working directory
# Out:
# Current working directory is: c:\Users\LENOVO\Documents\Python DS Vashisht

# %%
files = os.listdir() #listdir() is a function that returns a list of all files and directories in the specified directory
print('Files in current directory:', files)
# Out:
# Files in current directory: ['analysis1.ipynb', 'analysis2.ipynb', 'Basics.py', 'basics2.ipynb', 'Calculaytor.py', 'Dictionary.ipynb', 'FileHandling.ipynb', 'Functions.ipynb', 'graphs1.ipynb', 'graphs2.ipynb', 'laptops.csv', 'Library.ipynb', 'Numpy.ipynb', 'Sets.ipynb']

# %%
files = os.listdir(r'C:\Users\LENOVO\Documents\Analysis-of-Road-Accidents')
print('Files in specified directory:', files)
print('Number of files in specified directory:', len(files))
# Out:
# Files in specified directory: ['.git', 'analysis.ipynb', 'analysis2.ipynb', 'analysis3.ipynb', 'analysis4.ipynb', 'analysis5.ipynb', 'dataset', 'project.py', 'readme.md', 'requirements.txt', 'static', 'templates']
# Number of files in specified directory: 12

# %%
os.walk('C:') #walk() is a function that generates the file names in a directory tree by walking either top-down or bottom-up
# Out:
# <generator object _walk at 0x0000024144A45BA0>

# %%
total_files = 0
for path, folders, files in os.walk(r"C:\Users\LENOVO\Documents\Mern_11"):
    print('=>', path)
    print('📂', folders)
    print('📄', files)
    total_files += len(files)
print('Total files in directory tree:', total_files)
# Out:
# => C:\Users\LENOVO\Documents\Mern_11
# 📂 ['.git', '.vscode', 'backend', 'frontend', 'node_modules', 'section1']
# 📄 ['basics2.html', 'bsics.html', 'CSS.html', 'display.html', 'flex.html', 'font.jpg', 'form.html', 'grid.html', 'login.html', 'package-lock.json', 'package.json', 'semantics.html', 'style.CSS', 'table.html', 'table2.html', 'th (5).jpeg']
# => C:\Users\LENOVO\Documents\Mern_11\.git
# 📂 ['hooks', 'info', 'logs', 'objects', 'refs']
# 📄 ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# => C:\Users\LENOVO\Documents\Mern_11\.git\hooks
# 📂 []
# 📄 ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# => C:\Users\LENOVO\Documents\Mern_11\.git\info
# 📂 []
# 📄 ['exclude']
# ...

# %%
files=r'"D:\JAVA"'
if os.path.exists(files):
    print("The file exists")
else:
    print("The file does not exist")
# Out:
# The file does not exist
